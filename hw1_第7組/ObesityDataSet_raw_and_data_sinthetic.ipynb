# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score, recall_score, precision_score
from sklearn.metrics import precision_recall_fscore_support
import tensorflow as tf
from tensorflow.keras.models import Model,Sequential
from tensorflow.keras.layers import Input, Dense, Activation,Dropout

# %%
df_data=pd.read_csv('ObesityDataSet_raw_and_data_sinthetic.csv')
df_data
# Out:
#       Gender        Age    Height      Weight family_history_with_overweight  \
# 0     Female  21.000000  1.620000   64.000000                            yes
# 1     Female  21.000000  1.520000   56.000000                            yes
# 2       Male  23.000000  1.800000   77.000000                            yes
# 3       Male  27.000000  1.800000   87.000000                             no
# 4       Male  22.000000  1.780000   89.800000                             no
# ...      ...        ...       ...         ...                            ...
# 2106  Female  20.976842  1.710730  131.408528                            yes
# 2107  Female  21.982942  1.748584  133.742943                            yes
# 2108  Female  22.524036  1.752206  133.689352                            yes
# 2109  Female  24.361936  1.739450  133.346641                            yes
# 2110  Female  23.664709  1.738836  133.472641                            yes
#
#      FAVC  FCVC  NCP       CAEC SMOKE      CH2O  SCC       FAF       TUE  \
# 0      no   2.0  3.0  Sometimes    no  2.000000   no  0.000000  1.000000
# 1      no   3.0  3.0  Sometimes   yes  3.000000  yes  3.000000  0.000000
# 2      no   2.0  3.0  Sometimes    no  2.000000   no  2.000000  1.000000
# 3      no   3.0  3.0  Sometimes    no  2.000000   no  2.000000  0.000000
# 4      no   2.0  1.0  Sometimes    no  2.000000   no  0.000000  0.000000
# ...   ...   ...  ...        ...   ...       ...  ...       ...       ...
# 2106  yes   3.0  3.0  Sometimes    no  1.728139   no  1.676269  0.906247
# 2107  yes   3.0  3.0  Sometimes    no  2.005130   no  1.341390  0.599270
# 2108  yes   3.0  3.0  Sometimes    no  2.054193   no  1.414209  0.646288
# 2109  yes   3.0  3.0  Sometimes    no  2.852339   no  1.139107  0.586035
# 2110  yes   3.0  3.0  Sometimes    no  2.863513   no  1.026452  0.714137
#
#             CALC                 MTRANS           NObeyesdad
# 0             no  Public_Transportation        Normal_Weight
# 1      Sometimes  Public_Transportation        Normal_Weight
# 2     Frequently  Public_Transportation        Normal_Weight
# 3     Frequently                Walking   Overweight_Level_I
# 4      Sometimes  Public_Transportation  Overweight_Level_II
# ...          ...                    ...                  ...
# 2106   Sometimes  Public_Transportation     Obesity_Type_III
# 2107   Sometimes  Public_Transportation     Obesity_Type_III
# 2108   Sometimes  Public_Transportation     Obesity_Type_III
# 2109   Sometimes  Public_Transportation     Obesity_Type_III
# 2110   Sometimes  Public_Transportation     Obesity_Type_III
#
# [2111 rows x 17 columns]

# %%
#df_data['NObeyesdad'].value_counts()

# %%
# df_x
df_data.loc()[df_data['family_history_with_overweight']=='no','family_history_with_overweight']=0
df_data.loc()[df_data['family_history_with_overweight']=='yes','family_history_with_overweight']=1

df_data.loc()[df_data['FAVC']=='no','FAVC']=0
df_data.loc()[df_data['FAVC']=='yes','FAVC']=1

df_data.loc()[df_data['SMOKE']=='no','SMOKE']=0
df_data.loc()[df_data['SMOKE']=='yes','SMOKE']=1

df_data.loc()[df_data['SCC']=='no','SCC']=0
df_data.loc()[df_data['SCC']=='yes','SCC']=1

df_data.loc()[df_data['CAEC']=='No','CAEC']=1
df_data.loc()[df_data['CAEC']=='no','CAEC']=1
df_data.loc()[df_data['CAEC']=='Sometimes','CAEC']=2
df_data.loc()[df_data['CAEC']=='Frequently','CAEC']=3
df_data.loc()[df_data['CAEC']=='Always','CAEC']=4

df_data.loc()[df_data['CALC']=='no','CALC']=1
df_data.loc()[df_data['CALC']=='Sometimes','CALC']=2
df_data.loc()[df_data['CALC']=='Frequently','CALC']=3
df_data.loc()[df_data['CALC']=='Always','CALC']=4

df_data.loc()[df_data['Gender']=='Female','Gender']=0
df_data.loc()[df_data['Gender']=='Male','Gender']=1
df_data
df_data.loc()[df_data['MTRANS']=='Public_Transportation','MTRANS']=0
df_data.loc()[df_data['MTRANS']=='Walking','MTRANS']=1

df_data.loc()[df_data['NObeyesdad']=='Normal_Weight','NObeyesdad']=0
df_data.loc()[df_data['NObeyesdad']=='Obesity_Type_I','NObeyesdad']=1
df_data.loc()[df_data['NObeyesdad']=='Obesity_Type_II','NObeyesdad']=2

df_data.loc()[df_data['NObeyesdad']=='Obesity_Type_III','NObeyesdad']=3

df_data.loc()[df_data['NObeyesdad']=='Overweight_Level_I','NObeyesdad']=4
df_data.loc()[df_data['NObeyesdad']=='Overweight_Level_II','NObeyesdad']=5
df_data.loc()[df_data['NObeyesdad']=='Insufficient_Weight','NObeyesdad']=6

# %%
df_data[['family_history_with_overweight', 'FAVC', 'CAEC', 'SMOKE', 'SCC','CALC']]=df_data[
    ['family_history_with_overweight', 'FAVC', 'CAEC', 'SMOKE', 'SCC','CALC']
].astype(int)

# %%
df_x=df_data.drop(['NObeyesdad'],axis=1)
df_y=df_data.loc[:,'NObeyesdad']

x = pd.get_dummies(df_x)
y = pd.get_dummies(df_y)

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

# %%
#資料前處理

# %%
input_layer = Input(shape=(x_train.shape[1],))
dense_layer_1 =Dense(32,kernel_initializer=tf.keras.initializers.GlorotNormal() ,activation='relu', name ="nl1" )(input_layer)
dense_layer_2 = Dense(16,kernel_initializer=tf.keras.initializers.GlorotNormal(),activation='relu', name ="nl2" )(dense_layer_1)
dense_layer_2 = Dense(10,activation='relu', name ="nl3" )(dense_layer_2)
dense_layer_2 = Dense(10,activation='relu', name ="nl4" )(dense_layer_2)
dense_layer_2 = Dropout(0.5)(dense_layer_2)
output = Dense(y_train.shape[1],activation='softmax')(dense_layer_2)
model = Model(inputs=input_layer, outputs=output)
print(model.summary())
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 21)]              0
# _________________________________________________________________
# nl1 (Dense)                  (None, 32)                704
# _________________________________________________________________
# nl2 (Dense)                  (None, 16)                528
# _________________________________________________________________
# nl3 (Dense)                  (None, 10)                170
# _________________________________________________________________
# nl4 (Dense)                  (None, 10)                110
# _________________________________________________________________
# dropout (Dropout)            (None, 10)                0
# _________________________________________________________________
# dense (Dense)                (None, 7)                 77
# =================================================================
# Total params: 1,589
# Trainable params: 1,589
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
callback = tf.keras.callbacks.EarlyStopping(monitor='acc',mode='max', patience=5)
Adam = tf.optimizers.Adam(lr=0.003, beta_1=0.9, beta_2=0.997, epsilon=1e-08, decay=0.0)
model.compile(optimizer=Adam, 
              loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
              metrics = [tf.keras.metrics.Precision(),tf.keras.metrics.Recall(),tf.keras.metrics.Accuracy()]
              )
history = model.fit(x=x_train, y=y_train,  epochs=50,batch_size =5, callbacks=[callback] )
# Out:
# Epoch 1/50
# 338/338 [==============================] - 1s 533us/step - loss: 3.9283 - precision: 0.1464 - recall: 0.0257 - accuracy: 0.0000e+00
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,precision,recall,accuracy
# Epoch 2/50
# 338/338 [==============================] - 0s 521us/step - loss: 1.9219 - precision: 0.6279 - recall: 0.0049 - accuracy: 0.0000e+00
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,precision,recall,accuracy
# Epoch 3/50
# 338/338 [==============================] - 0s 542us/step - loss: 1.7621 - precision: 0.5561 - recall: 0.0560 - accuracy: 0.0000e+00
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,precision,recall,accuracy
# Epoch 4/50
# 338/338 [==============================] - 0s 518us/step - loss: 1.6551 - precision: 0.6313 - recall: 0.0863 - accuracy: 0.0000e+00
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,precision,recall,accuracy
# Epoch 5/50
# 338/338 [==============================] - 0s 524us/step - loss: 1.6080 - precision: 0.7227 - recall: 0.1034 - accuracy: 0.0000e+00
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,precision,recall,accuracy
# Epoch 6/50
# 338/338 [==============================] - 0s 521us/step - loss: 1.5759 - precision: 0.6487 - recall: 0.1258 - accuracy: 0.0000e+00
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,precision,recall,accuracy
# Epoch 7/50
# 338/338 [==============================] - 0s 522us/step - loss: 1.5953 - precision: 0.6428 - recall: 0.1138 - accuracy: 0.0000e+00
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,precision,recall,accuracy
# Epoch 8/50
# 338/338 [==============================] - 0s 524us/step - loss: 1.6523 - precision: 0.6802 - recall: 0.0835 - accuracy: 0.0000e+00
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,precision,recall,accuracy
# Epoch 9/50
# 338/338 [==============================] - 0s 518us/step - loss: 1.5615 - precision: 0.6336 - recall: 0.1158 - accuracy: 4.4866e-05
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,precision,recall,accuracy
# Epoch 10/50
# 338/338 [==============================] - 0s 527us/step - loss: 1.4591 - precision: 0.6311 - recall: 0.1447 - accuracy: 4.7862e-04
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,precision,recall,accuracy
# Epoch 11/50
# 338/338 [==============================] - 0s 524us/step - loss: 1.3392 - precision: 0.6765 - recall: 0.1829 - accuracy: 7.1350e-04
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,precision,recall,accuracy
# Epoch 12/50
# 338/338 [==============================] - 0s 524us/step - loss: 1.3766 - precision: 0.6387 - recall: 0.1246 - accuracy: 0.0022
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,precision,recall,accuracy
# Epoch 13/50
# 338/338 [==============================] - 0s 520us/step - loss: 1.3690 - precision: 0.6449 - recall: 0.1604 - accuracy: 0.0084
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,precision,recall,accuracy
# Epoch 14/50
# 338/338 [==============================] - 0s 532us/step - loss: 1.3606 - precision: 0.6487 - recall: 0.1592 - accuracy: 0.0154
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,precision,recall,accuracy
# Epoch 15/50
# 338/338 [==============================] - 0s 519us/step - loss: 1.2965 - precision: 0.6889 - recall: 0.1997 - accuracy: 0.0205
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,precision,recall,accuracy
# Epoch 16/50
# 338/338 [==============================] - 0s 532us/step - loss: 1.3354 - precision: 0.6845 - recall: 0.1575 - accuracy: 0.0216
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,precision,recall,accuracy
# Epoch 17/50
# 338/338 [==============================] - 0s 536us/step - loss: 1.3063 - precision: 0.6507 - recall: 0.1760 - accuracy: 0.0334
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,precision,recall,accuracy
# Epoch 18/50
# 338/338 [==============================] - 0s 533us/step - loss: 1.2764 - precision: 0.6685 - recall: 0.1881 - accuracy: 0.0385
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,precision,recall,accuracy
# Epoch 19/50
# 338/338 [==============================] - 0s 521us/step - loss: 1.2433 - precision: 0.6944 - recall: 0.2217 - accuracy: 0.0458
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,precision,recall,accuracy
# Epoch
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,precision,recall,accuracy
# Epoch 43/50
# 338/338 [==============================] - 0s 527us/step - loss: 0.9411 - precision: 0.6944 - recall: 0.4014 - accuracy: 0.0810
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,precision,recall,accuracy
# Epoch 44/50
# 338/338 [==============================] - 0s 571us/step - loss: 0.9350 - precision: 0.7126 - recall: 0.4096 - accuracy: 0.0782
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,precision,recall,accuracy
# Epoch 45/50
# 338/338 [==============================] - 0s 592us/step - loss: 0.8677 - precision: 0.7103 - recall: 0.5309 - accuracy: 0.0945
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,precision,recall,accuracy
# Epoch 46/50
# 338/338 [==============================] - 0s 530us/step - loss: 0.8912 - precision: 0.7040 - recall: 0.4663 - accuracy: 0.0856
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,precision,recall,accuracy
# Epoch 47/50
# 338/338 [==============================] - 0s 527us/step - loss: 0.8811 - precision: 0.6986 - recall: 0.5172 - accuracy: 0.0956
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,precision,recall,accuracy
# Epoch 48/50
# 338/338 [==============================] - 0s 512us/step - loss: 0.8818 - precision: 0.7116 - recall: 0.5127 - accuracy: 0.1001
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,precision,recall,accuracy
# Epoch 49/50
# 338/338 [==============================] - 0s 535us/step - loss: 0.8970 - precision: 0.6996 - recall: 0.5036 - accuracy: 0.0903
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,precision,recall,accuracy
# Epoch 50/50
# 338/338 [==============================] - 0s 568us/step - loss: 0.9238 - precision: 0.6522 - recall: 0.4451 - accuracy: 0.1005
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,precision,recall,accuracy

# %%
preds = model.evaluate(x = x_test, y = y_test)

F1 = 2 * (preds[1] * preds[2]) / (preds[1] + preds[2])
print(preds)
print(F1)
# Out:
# 14/14 [==============================] - 0s 537us/step - loss: 0.6321 - precision: 0.8129 - recall: 0.6572 - accuracy: 0.1142
# [0.6320796608924866, 0.8128654956817627, 0.6572104096412659, 0.11415062844753265]
# 0.7267973898026358

# %%
reds = model.evaluate(x = x_test, y = y_test)

F1 = 2 * (preds[1] * preds[2]) / (preds[1] + preds[2])
print('Precision', preds[1])
print('Recall}', preds[2])
print('F1',F1)
# Out:
# 14/14 [==============================] - 0s 614us/step - loss: 0.6321 - precision: 0.8129 - recall: 0.6572 - accuracy: 0.1142
# Precision 0.8128654956817627
# Recall} 0.6572104096412659
# F1 0.7267973898026358

# %%
pd.DataFrame(history.history).plot(figsize = (8, 5))
plt.grid(True)
plt.gca().set_ylim(0, 2.5)
plt.show()

# %% [markdown]
# # value

# %%
df_data.drop(['NObeyesdad'],axis=1)
# Out:
#      Gender        Age    Height      Weight  family_history_with_overweight  \
# 0         0  21.000000  1.620000   64.000000                               1
# 1         0  21.000000  1.520000   56.000000                               1
# 2         1  23.000000  1.800000   77.000000                               1
# 3         1  27.000000  1.800000   87.000000                               0
# 4         1  22.000000  1.780000   89.800000                               0
# ...     ...        ...       ...         ...                             ...
# 2106      0  20.976842  1.710730  131.408528                               1
# 2107      0  21.982942  1.748584  133.742943                               1
# 2108      0  22.524036  1.752206  133.689352                               1
# 2109      0  24.361936  1.739450  133.346641                               1
# 2110      0  23.664709  1.738836  133.472641                               1
#
#       FAVC  FCVC  NCP  CAEC  SMOKE      CH2O  SCC       FAF       TUE  CALC  \
# 0        0   2.0  3.0     2      0  2.000000    0  0.000000  1.000000     1
# 1        0   3.0  3.0     2      1  3.000000    1  3.000000  0.000000     2
# 2        0   2.0  3.0     2      0  2.000000    0  2.000000  1.000000     3
# 3        0   3.0  3.0     2      0  2.000000    0  2.000000  0.000000     3
# 4        0   2.0  1.0     2      0  2.000000    0  0.000000  0.000000     2
# ...    ...   ...  ...   ...    ...       ...  ...       ...       ...   ...
# 2106     1   3.0  3.0     2      0  1.728139    0  1.676269  0.906247     2
# 2107     1   3.0  3.0     2      0  2.005130    0  1.341390  0.599270     2
# 2108     1   3.0  3.0     2      0  2.054193    0  1.414209  0.646288     2
# 2109     1   3.0  3.0     2      0  2.852339    0  1.139107  0.586035     2
# 2110     1   3.0  3.0     2      0  2.863513    0  1.026452  0.714137     2
#
#      MTRANS
# 0         0
# 1         0
# 2         0
# 3         1
# 4         0
# ...     ...
# 2106      0
# 2107      0
# 2108      0
# 2109      0
# 2110      0
#
# [2111 rows x 16 columns]

# %%
df_x=df_data.drop(['Height'],axis=1)

df_y=df_data.loc[:,'Height']

# %%
x = pd.get_dummies(df_x)
y = df_y

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

# %%
input_layer = Input(shape=(x_train.shape[1],))
dense_layer_1 =Dense(32,kernel_initializer=tf.keras.initializers.GlorotNormal() ,activation='relu', name ="nl1" )(input_layer)
dense_layer_2 = Dense(16,kernel_initializer=tf.keras.initializers.GlorotNormal(),activation='relu', name ="nl2" )(dense_layer_1)
dense_layer_2 = Dense(10,activation='relu', name ="nl3" )(dense_layer_2)
dense_layer_2 = Dense(10,activation='relu', name ="nl4" )(dense_layer_2)
dense_layer_2 = Dropout(0.5)(dense_layer_2)
output = Dense(1)(dense_layer_2)
model = Model(inputs=input_layer, outputs=output)
print(model.summary())
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 27)]              0
# _________________________________________________________________
# nl1 (Dense)                  (None, 32)                896
# _________________________________________________________________
# nl2 (Dense)                  (None, 16)                528
# _________________________________________________________________
# nl3 (Dense)                  (None, 10)                170
# _________________________________________________________________
# nl4 (Dense)                  (None, 10)                110
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 10)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 1,715
# Trainable params: 1,715
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
callback = tf.keras.callbacks.EarlyStopping(monitor='loss',mode='min', patience=5)
Adam = tf.optimizers.Adam(lr=0.003, beta_1=0.9, beta_2=0.997, epsilon=1e-08, decay=0.0)
model.compile(optimizer=Adam, 
              loss=[tf.keras.losses.mae],
              metrics=[tf.keras.metrics.mae,tf.keras.metrics.mape,tf.metrics.mse]
              
              )
history = model.fit(x=x_train, y=y_train,  epochs=50,batch_size =5, callbacks=[callback] )
# Out:
# Epoch 1/50
# 338/338 [==============================] - 1s 518us/step - loss: 0.7372 - mean_absolute_error: 0.7372 - mean_absolute_percentage_error: 43.1911 - mean_squared_error: 0.8708
# Epoch 2/50
# 338/338 [==============================] - 0s 524us/step - loss: 0.3640 - mean_absolute_error: 0.3640 - mean_absolute_percentage_error: 21.2537 - mean_squared_error: 0.2052
# Epoch 3/50
# 338/338 [==============================] - 0s 542us/step - loss: 0.1429 - mean_absolute_error: 0.1429 - mean_absolute_percentage_error: 8.3233 - mean_squared_error: 0.0338
# Epoch 4/50
# 338/338 [==============================] - 0s 565us/step - loss: 0.0672 - mean_absolute_error: 0.0672 - mean_absolute_percentage_error: 3.9262 - mean_squared_error: 0.0073
# Epoch 5/50
# 338/338 [==============================] - 0s 529us/step - loss: 0.0630 - mean_absolute_error: 0.0630 - mean_absolute_percentage_error: 3.7118 - mean_squared_error: 0.0061
# Epoch 6/50
# 338/338 [==============================] - 0s 522us/step - loss: 0.0633 - mean_absolute_error: 0.0633 - mean_absolute_percentage_error:
- mean_absolute_error: 0.0534 - mean_absolute_percentage_error: 3.1617 - mean_squared_error: 0.0045
# Epoch 30/50
# 338/338 [==============================] - 0s 524us/step - loss: 0.0529 - mean_absolute_error: 0.0529 - mean_absolute_percentage_error: 3.1064 - mean_squared_error: 0.0046
# Epoch 31/50
# 338/338 [==============================] - 0s 523us/step - loss: 0.0525 - mean_absolute_error: 0.0525 - mean_absolute_percentage_error: 3.0905 - mean_squared_error: 0.0044
# Epoch 32/50
# 338/338 [==============================] - 0s 518us/step - loss: 0.0552 - mean_absolute_error: 0.0552 - mean_absolute_percentage_error: 3.2570 - mean_squared_error: 0.0049
# Epoch 33/50
# 338/338 [==============================] - 0s 514us/step - loss: 0.0559 - mean_absolute_error: 0.0559 - mean_absolute_percentage_error: 3.2850 - mean_squared_error: 0.0049
# Epoch 34/50
# 338/338 [==============================] - 0s 515us/step - loss: 0.0533 - mean_absolute_error: 0.0533 - mean_absolute_percentage_error: 3.1632 - mean_squared_error: 0.0046
# Epoch 35/50
# 338/338 [==============================] - 0s 521us/step - loss: 0.0548 - mean_absolute_error: 0.0548 - mean_absolute_percentage_error: 3.2334 - mean_squared_error: 0.0048
# Epoch 36/50
# 338/338 [==============================] - 0s 524us/step - loss: 0.0542 - mean_absolute_error: 0.0542 - mean_absolute_percentage_error: 3.1905 - mean_squared_error: 0.0048
# Epoch 37/50
# 338/338 [==============================] - 0s 521us/step - loss: 0.0531 - mean_absolute_error: 0.0531 - mean_absolute_percentage_error: 3.1288 - mean_squared_error: 0.0046
# Epoch 38/50
# 338/338 [==============================] - 0s 521us/step - loss: 0.0521 - mean_absolute_error: 0.0521 - mean_absolute_percentage_error: 3.0492 - mean_squared_error: 0.0045
# Epoch 39/50
# 338/338 [==============================] - 0s 515us/step - loss: 0.0509 - mean_absolute_error: 0.0509 - mean_absolute_percentage_error: 2.9915 - mean_squared_error: 0.0044
# Epoch 40/50
# 338/338 [==============================] - 0s 515us/step - loss: 0.0516 - mean_absolute_error: 0.0516 - mean_absolute_percentage_error: 3.0267 - mean_squared_error: 0.0043
# Epoch 41/50
# 338/338 [==============================] - 0s 514us/step - loss: 0.0536 - mean_absolute_error: 0.0536 - mean_absolute_percentage_error: 3.1486 - mean_squared_error: 0.0047
# Epoch 42/50
# 338/338 [==============================] - 0s 516us/step - loss: 0.0503 - mean_absolute_error: 0.0503 - mean_absolute_percentage_error: 2.9609 - mean_squared_error: 0.0044
# Epoch 43/50
# 338/338 [==============================] - 0s 512us/step - loss: 0.0512 - mean_absolute_error: 0.0512 - mean_absolute_percentage_error: 3.0185 - mean_squared_error: 0.0043
# Epoch 44/50
# 338/338 [==============================] - 0s 515us/step - loss: 0.0504 - mean_absolute_error: 0.0504 - mean_absolute_percentage_error: 2.9610 - mean_squared_error: 0.0042
# Epoch 45/50
# 338/338 [==============================] - 0s 515us/step - loss: 0.0497 - mean_absolute_error: 0.0497 - mean_absolute_percentage_error: 2.9272 - mean_squared_error: 0.0042
# Epoch 46/50
# 338/338 [==============================] - 0s 515us/step - loss: 0.0492 - mean_absolute_error: 0.0492 - mean_absolute_percentage_error: 2.9098 - mean_squared_error: 0.0041
# Epoch 47/50
# 338/338 [==============================] - 0s 515us/step - loss: 0.0487 - mean_absolute_error: 0.0487 - mean_absolute_percentage_error: 2.8701 - mean_squared_error: 0.0040
# Epoch 48/50
# 338/338 [==============================] - 0s 515us/step - loss: 0.0476 - mean_absolute_error: 0.0476 - mean_absolute_percentage_error: 2.8031 - mean_squared_error: 0.0038
# Epoch 49/50
# 338/338 [==============================] - 0s 515us/step - loss: 0.0527 - mean_absolute_error: 0.0527 - mean_absolute_percentage_error: 3.0835 - mean_squared_error: 0.0046
# Epoch 50/50
# 338/338 [==============================] - 0s 515us/step - loss: 0.0508 - mean_absolute_error: 0.0508 - mean_absolute_percentage_error: 2.9895 - mean_squared_error: 0.0045

# %% [markdown]
# callback = tf.keras.callbacks.EarlyStopping(monitor='acc',mode='max', patience=5)
# Adam = tf.optimizers.Adam(lr=0.003, beta_1=0.9, beta_2=0.997, epsilon=1e-08, decay=0.0)
# model.compile(optimizer=Adam,
#               loss=["mean_squared_error"],metrics=['mean_squared_error','mean_absolute_error'])
# history = model.fit(x=x_train, y=y_train,  epochs=50,batch_size =5, callbacks=[callback] )

# %%
df_test_y_predicted = model.predict(x_test)

# %%
import numpy as np
from sklearn.metrics import mean_squared_error
print('MSE为：',np.sqrt(mean_squared_error(y_test,df_test_y_predicted)))
# Out:
# MSE为： 0.05874691159806977

# %%
from sklearn.metrics import mean_absolute_error
print('MAE为：',mean_absolute_error(y_test,df_test_y_predicted))
# Out:
# MAE为： 0.0463304374909818

# %%
def mean_absolute_percentage_error(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
mean_absolute_percentage_error(y_test,df_test_y_predicted)
# Out:
# 5.196542784347013

# %%
history.history['mean_absolute_percentage_error']=list(map(lambda x:x/100, history.history['mean_absolute_percentage_error']))
pd.DataFrame(history.history).plot(figsize = (8, 5))
plt.grid(True)
plt.gca().set_ylim(0, 1)
plt.show()
