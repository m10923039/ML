# %%
#Adult_data.csv
import pandas as pd

# %%
df = pd.read_csv("Adult.data", header=None)
df_0=df

# %%
df_0.columns=["age",
              "workclass",
              "fnlwgt",
              "education",
              "education_num",
              "marital_status",
              "occupation",
              "relationship",
              "race",
              "sex",
              "capital_gain",
              "capital_loss",
              "hours_per_week",
              "native_country",
              "salary"
             ]

# %%
df_0.to_csv("AdultsDataSet_train.csv",index=False)
df_0
# Out:
#        age          workclass  fnlwgt    education  education_num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital_status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# 1       Married-civ-spouse     Exec-managerial         Husband   White
# 2                 Divorced   Handlers-cleaners   Not-in-family   White
# 3       Married-civ-spouse   Handlers-cleaners         Husband   Black
# 4       Married-civ-spouse      Prof-specialty            Wife   Black
# ...                    ...                 ...             ...     ...
# 32556   Married-civ-spouse        Tech-support            Wife   White
# 32557   Married-civ-spouse   Machine-op-inspct         Husband   White
# 32558              Widowed        Adm-clerical       Unmarried   White
# 32559        Never-married        Adm-clerical       Own-child   White
# 32560   Married-civ-spouse     Exec-managerial            Wife   White
#
#            sex  capital_gain  capital_loss  hours_per_week  native_country  \
# 0         Male          2174             0              40   United-States
# 1         Male             0             0              13   United-States
# 2         Male             0             0              40   United-States
# 3         Male             0             0              40   United-States
# 4       Female             0             0              40            Cuba
# ...        ...           ...           ...             ...             ...
# 32556   Female             0             0              38   United-States
# 32557     Male             0             0              40   United-States
# 32558   Female             0             0              40   United-States
# 32559     Male             0             0              20   United-States
# 32560   Female         15024             0              40   United-States
#
#        salary
# 0       <=50K
# 1       <=50K
# 2       <=50K
# 3       <=50K
# 4       <=50K
# ...       ...
# 32556   <=50K
# 32557    >50K
# 32558   <=50K
# 32559   <=50K
# 32560    >50K
#
# [32561 rows x 15 columns]

# %%
df_4 =pd.read_csv("AdultsDataSet_train.csv")
# Out:
#        age          workclass  fnlwgt    education  education_num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital_status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# 1       Married-civ-spouse     Exec-managerial         Husband   White
# 2                 Divorced   Handlers-cleaners   Not-in-family   White
# 3       Married-civ-spouse   Handlers-cleaners         Husband   Black
# 4       Married-civ-spouse      Prof-specialty            Wife   Black
# ...                    ...                 ...             ...     ...
# 32556   Married-civ-spouse        Tech-support            Wife   White
# 32557   Married-civ-spouse   Machine-op-inspct         Husband   White
# 32558              Widowed        Adm-clerical       Unmarried   White
# 32559        Never-married        Adm-clerical       Own-child   White
# 32560   Married-civ-spouse     Exec-managerial            Wife   White
#
#            sex  capital_gain  capital_loss  hours_per_week  native_country  \
# 0         Male          2174             0              40   United-States
# 1         Male             0             0              13   United-States
# 2         Male             0             0              40   United-States
# 3         Male             0             0              40   United-States
# 4       Female             0             0              40            Cuba
# ...        ...           ...           ...             ...             ...
# 32556   Female             0             0              38   United-States
# 32557     Male             0             0              40   United-States
# 32558   Female             0             0              40   United-States
# 32559     Male             0             0              20   United-States
# 32560   Female         15024             0              40   United-States
#
#        salary
# 0       <=50K
# 1       <=50K
# 2       <=50K
# 3       <=50K
# 4       <=50K
# ...       ...
# 32556   <=50K
# 32557    >50K
# 32558   <=50K
# 32559   <=50K
# 32560    >50K
#
# [32561 rows x 15 columns]

# %%
#native_country
df_4['native_country'].value_counts()

fliter1 = (df_4["native_country"] != ' ?')
fliter2 = (df_4["occupation"] != ' ?')
fliter3 = (df_4["workclass"] != ' ?')
df_5 = df_4[fliter1 & fliter2 & fliter3]
print(df_5['native_country'].value_counts())
print(df_5['occupation'].value_counts())
print(df_5['workclass'].value_counts())
# Out:
#  United-States                 27504
#  Mexico                          610
#  Philippines                     188
#  Germany                         128
#  Puerto-Rico                     109
#  Canada                          107
#  El-Salvador                     100
#  India                           100
#  Cuba                             92
#  England                          86
#  Jamaica                          80
#  South                            71
#  Italy                            68
#  China                            68
#  Dominican-Republic               67
#  Vietnam                          64
#  Guatemala                        63
#  Japan                            59
#  Poland                           56
#  Columbia                         56
#  Taiwan                           42
#  Haiti                            42
#  Iran                             42
#  Portugal                         34
#  Nicaragua                        33
#  Peru                             30
#  Greece                           29
#  France                           27
#  Ecuador                          27
#  Ireland                          24
#  Hong                             19
#  Trinadad&Tobago                  18
#  Cambodia                         18
#  Thailand                         17
#  Laos                             17
#  Yugoslavia                       16
#  Outlying-US(Guam-USVI-etc)       14
#  Hungary                          13
#  Honduras                         12
#  Scotland                         11
#  Holand-Netherlands                1
# Name: native_country, dtype: int64
#  Prof-specialty       4038
#  Craft-repair         4030
#  Exec-managerial      3992
#  Adm-clerical         3721
#  Sales                3584
#  Other-service        3212
#  Machine-op-inspct    1966
#  Transport-moving     1572
#  Handlers-cleaners    1350
#  Farming-fishing       989
#  Tech-support          912
#  Protective-serv       644
#  Priv-house-serv       143
#  Armed-Forces            9
# Name: occupation, dtype: int64
#  Private             22286
#  Self-emp-not-inc     2499
#  Local-gov            2067
#  State-gov            1279
#  Self-emp-inc         1074
#  Federal-gov           943
#  Without-pay            14
# Name: workclass, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
df_6 = df_5
df_6['workclass'] = labelencoder.fit_transform(df_5['workclass'])
df_6['occupation'] = labelencoder.fit_transform(df_5['occupation'])
df_6['marital_status'] = labelencoder.fit_transform(df_5['marital_status'])
df_6['relationship'] = labelencoder.fit_transform(df_5['relationship'])
df_6['race'] = labelencoder.fit_transform(df_5['race'])
df_6['sex'] = labelencoder.fit_transform(df_5['sex'])
df_6['native_country'] = labelencoder.fit_transform(df_5['native_country'])
df_6['salary'] = labelencoder.fit_transform(df_5['salary'])
df_6['education'] = labelencoder.fit_transform(df_5['education'])
df_6
# Out:
# <ipython-input-8-d626d242917b>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_6['workclass'] = labelencoder.fit_transform(df_5['workclass'])
# <ipython-input-8-d626d242917b>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_6['occupation'] = labelencoder.fit_transform(df_5['occupation'])
# <ipython-input-8-d626d242917b>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_6['marital_status'] = labelencoder.fit_transform(df_5['marital_status'])
# <ipython-input-8-d626d242917b>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_6['relationship'] = labelencoder.fit_transform(df_5['relationship'])
# <ipython-input-8-d626d242917b>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_6['race'] = labelencoder.fit_transform(df_5['race'])
# <ipython-input-8-d626d242917b>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_6['sex'] = labelencoder.fit_transform(df_5['sex'])
# <ipython-input-8-d626d242917b>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_6['native_country'] = labelencoder.fit_transform(df_5['native_country'])
# <ipython-input-8-d626d242917b>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_6['salary'] = labelencoder.fit_transform(df_5['salary'])
# <ipython-input-8-d626d242917b>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_6['education'] = labelencoder.fit_transform(df_5['education'])
#        age  workclass  fnlwgt  education  education_num  marital_status  \
# 0       39          5   77516          9             13               4
# 1       50          4   83311          9             13               2
# 2       38          2  215646         11              9               0
# 3       53          2  234721          1              7               2
# 4       28          2  338409          9             13               2
# ...    ...        ...     ...        ...            ...             ...
# 32556   27          2  257302          7             12               2
# 32557   40          2  154374         11              9               2
# 32558   58          2  151910         11              9               6
# 32559   22          2  201490         11              9               4
# 32560   52          3  287927         11              9               2
#
#        occupation  relationship  race  sex  capital_gain  capital_loss  \
# 0               0             1     4    1          2174             0
# 1               3             0     4    1             0             0
# 2               5             1     4    1             0             0
# 3               5             0     2    1             0             0
# 4               9             5     2    0             0             0
# ...           ...           ...   ...  ...           ...           ...
# 32556          12             5     4    0             0             0
# 32557           6             0     4    1             0             0
# 32558           0             4     4    0             0             0
# 32559           0             3     4    1             0             0
# 32560           3             5     4    0         15024             0
#
#        hours_per_week  native_country  salary
# 0                  40              38       0
# 1                  13              38       0
# 2                  40              38       0
# 3                  40              38       0
# 4                  40               4       0
# ...               ...             ...     ...
# 32556              38              38       0
# 32557              40              38       1
# 32558              40              38       0
# 32559              20              38       0
# 32560              40              38       1
#
# [30162 rows x 15 columns]

# %%
df_6.to_csv("AdultsDataSet_Finaltrain.csv",index=False)

# %% [markdown]
# # NN

# %%
import pandas as pd

# %%
train = pd.read_csv("AdultsDataSet_Finaltrain.csv")
train
# Out:
#        age  workclass  fnlwgt  education  education_num  marital_status  \
# 0       39          5   77516          9             13               4
# 1       50          4   83311          9             13               2
# 2       38          2  215646         11              9               0
# 3       53          2  234721          1              7               2
# 4       28          2  338409          9             13               2
# ...    ...        ...     ...        ...            ...             ...
# 30157   27          2  257302          7             12               2
# 30158   40          2  154374         11              9               2
# 30159   58          2  151910         11              9               6
# 30160   22          2  201490         11              9               4
# 30161   52          3  287927         11              9               2
#
#        occupation  relationship  race  sex  capital_gain  capital_loss  \
# 0               0             1     4    1          2174             0
# 1               3             0     4    1             0             0
# 2               5             1     4    1             0             0
# 3               5             0     2    1             0             0
# 4               9             5     2    0             0             0
# ...           ...           ...   ...  ...           ...           ...
# 30157          12             5     4    0             0             0
# 30158           6             0     4    1             0             0
# 30159           0             4     4    0             0             0
# 30160           0             3     4    1             0             0
# 30161           3             5     4    0         15024             0
#
#        hours_per_week  native_country  salary
# 0                  40              38       0
# 1                  13              38       0
# 2                  40              38       0
# 3                  40              38       0
# 4                  40               4       0
# ...               ...             ...     ...
# 30157              38              38       0
# 30158              40              38       1
# 30159              40              38       0
# 30160              20              38       0
# 30161              40              38       1
#
# [30162 rows x 15 columns]

# %%
# normalize
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
train1 = scaler.fit_transform(train)
train2 = pd.DataFrame(train1,columns=train.columns)
train2
# Out:
#             age  workclass    fnlwgt  education  education_num  \
# 0      0.301370   0.833333  0.043338   0.600000       0.800000
# 1      0.452055   0.666667  0.047277   0.600000       0.800000
# 2      0.287671   0.333333  0.137244   0.733333       0.533333
# 3      0.493151   0.333333  0.150212   0.066667       0.400000
# 4      0.150685   0.333333  0.220703   0.600000       0.800000
# ...         ...        ...       ...        ...            ...
# 30157  0.136986   0.333333  0.165563   0.466667       0.733333
# 30158  0.315068   0.333333  0.095589   0.733333       0.533333
# 30159  0.561644   0.333333  0.093914   0.733333       0.533333
# 30160  0.068493   0.333333  0.127620   0.733333       0.533333
# 30161  0.479452   0.500000  0.186383   0.733333       0.533333
#
#        marital_status  occupation  relationship  race  sex  capital_gain  \
# 0            0.666667    0.000000           0.2   1.0  1.0      0.021740
# 1            0.333333    0.230769           0.0   1.0  1.0      0.000000
# 2            0.000000    0.384615           0.2   1.0  1.0      0.000000
# 3            0.333333    0.384615           0.0   0.5  1.0      0.000000
# 4            0.333333    0.692308           1.0   0.5  0.0      0.000000
# ...               ...         ...           ...   ...  ...           ...
# 30157        0.333333    0.923077           1.0   1.0  0.0      0.000000
# 30158        0.333333    0.461538           0.0   1.0  1.0      0.000000
# 30159        1.000000    0.000000           0.8   1.0  0.0      0.000000
# 30160        0.666667    0.000000           0.6   1.0  1.0      0.000000
# 30161        0.333333    0.230769           1.0   1.0  0.0      0.150242
#
#        capital_loss  hours_per_week  native_country  salary
# 0               0.0        0.397959            0.95     0.0
# 1               0.0        0.122449            0.95     0.0
# 2               0.0        0.397959            0.95     0.0
# 3               0.0        0.397959            0.95     0.0
# 4               0.0        0.397959            0.10     0.0
# ...             ...             ...             ...     ...
# 30157           0.0        0.377551            0.95     0.0
# 30158           0.0        0.397959            0.95     1.0
# 30159           0.0        0.397959            0.95     0.0
# 30160           0.0        0.193878            0.95     0.0
# 30161           0.0        0.397959            0.95     1.0
#
# [30162 rows x 15 columns]

# %%
train_X = train2.drop('education', axis=1)
train_y = train2['education']

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score, recall_score, precision_score
from sklearn.metrics import precision_recall_fscore_support
import tensorflow as tf
from tensorflow.keras.models import Model,Sequential
from tensorflow.keras.layers import Input, Dense, Activation,Dropout

x = pd.get_dummies(train_X)
y = pd.get_dummies(train_y)

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

# %%
input_layer = Input(shape=(x_train.shape[1],))
dense_layer_1 =Dense(32,kernel_initializer=tf.keras.initializers.GlorotNormal() ,activation='relu', name ="nl1" )(input_layer)
dense_layer_2 = Dense(16,kernel_initializer=tf.keras.initializers.GlorotNormal(),activation='relu', name ="nl2" )(dense_layer_1)
dense_layer_2 = Dense(10,activation='relu', name ="nl3" )(dense_layer_2)
dense_layer_2 = Dense(10,activation='relu', name ="nl4" )(dense_layer_2)
dense_layer_2 = Dropout(0.5)(dense_layer_2)
output = Dense(y_train.shape[1],activation='softmax')(dense_layer_2)
model = Model(inputs=input_layer, outputs=output)
print(model.summary())
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 14)]              0
# _________________________________________________________________
# nl1 (Dense)                  (None, 32)                480
# _________________________________________________________________
# nl2 (Dense)                  (None, 16)                528
# _________________________________________________________________
# nl3 (Dense)                  (None, 10)                170
# _________________________________________________________________
# nl4 (Dense)                  (None, 10)                110
# _________________________________________________________________
# dropout (Dropout)            (None, 10)                0
# _________________________________________________________________
# dense (Dense)                (None, 16)                176
# =================================================================
# Total params: 1,464
# Trainable params: 1,464
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
callback = tf.keras.callbacks.EarlyStopping(monitor='acc',mode='max', patience=5)
Adam = tf.optimizers.Adam(lr=0.003, beta_1=0.9, beta_2=0.997, epsilon=1e-08, decay=0.0)
model.compile(optimizer=Adam, 
              loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
              metrics = [tf.keras.metrics.Precision(),tf.keras.metrics.Recall(),tf.keras.metrics.Accuracy()]
              )
history = model.fit(x=x_train, y=y_train,  epochs=50,batch_size =5, callbacks=[callback] )
# Out:
# Epoch 1/50
# 4826/4826 [==============================] - 3s 546us/step - loss: 1.9323 - precision: 0.4847 - recall: 0.0796 - accuracy: 8.8760e-04
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,precision,recall,accuracy
# Epoch 2/50
# 4826/4826 [==============================] - 3s 537us/step - loss: 1.0526 - precision: 0.7891 - recall: 0.5272 - accuracy: 0.0701
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,precision,recall,accuracy
# Epoch 3/50
# 4826/4826 [==============================] - 3s 539us/step - loss: 1.0016 - precision: 0.8128 - recall: 0.5478 - accuracy: 0.1599
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,precision,recall,accuracy
# Epoch 4/50
# 4826/4826 [==============================] - 3s 540us/step - loss: 0.9397 - precision: 0.7786 - recall: 0.6270 - accuracy: 0.2147
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,precision,recall,accuracy
# Epoch 5/50
# 4826/4826 [==============================] - 3s 528us/step - loss: 0.9030 - precision: 0.7868 - recall: 0.6413 - accuracy: 0.2322
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,precision,recall,accuracy
# Epoch 6/50
# 4826/4826 [==============================] - 3s 542us/step - loss: 0.8464 - precision: 0.8045 - recall: 0.6593 - accuracy: 0.2459
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,precision,recall,accuracy
# Epoch
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,precision,recall,accuracy
# Epoch 31/50
# 4826/4826 [==============================] - 3s 535us/step - loss: 0.6509 - precision: 0.8611 - recall: 0.7990 - accuracy: 0.2318
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,precision,recall,accuracy
# Epoch 32/50
# 4826/4826 [==============================] - 2s 513us/step - loss: 0.6632 - precision: 0.8599 - recall: 0.7949 - accuracy: 0.2349
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,precision,recall,accuracy
# Epoch 33/50
# 4826/4826 [==============================] - 2s 504us/step - loss: 0.7193 - precision: 0.8409 - recall: 0.7816 - accuracy: 0.2226
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,precision,recall,accuracy
# Epoch 34/50
# 4826/4826 [==============================] - 3s 533us/step - loss: 0.6289 - precision: 0.8675 - recall: 0.8034 - accuracy: 0.2480
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,precision,recall,accuracy
# Epoch 35/50
# 4826/4826 [==============================] - 3s 711us/step - loss: 0.8328 - precision: 0.8149 - recall: 0.7519 - accuracy: 0.2345
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,precision,recall,accuracy
# Epoch 36/50
# 4826/4826 [==============================] - 3s 531us/step - loss: 0.8558 - precision: 0.7941 - recall: 0.7315 - accuracy: 0.2617
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,precision,recall,accuracy
# Epoch 37/50
# 4826/4826 [==============================] - 3s 604us/step - loss: 0.7629 - precision: 0.8205 - recall: 0.7534 - accuracy: 0.2907
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,precision,recall,accuracy
# Epoch 38/50
# 4826/4826 [==============================] - 3s 565us/step - loss: 0.8228 - precision: 0.8111 - recall: 0.7405 - accuracy: 0.2833
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,precision,recall,accuracy
# Epoch 39/50
# 4826/4826 [==============================] - 3s 530us/step - loss: 0.8717 - precision: 0.7953 - recall: 0.7272 - accuracy: 0.2762
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,precision,recall,accuracy
# Epoch 40/50
# 4826/4826 [==============================] - 3s 536us/step - loss: 0.8671 - precision: 0.8165 - recall: 0.7462 - accuracy: 0.2803
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,precision,recall,accuracy
# Epoch 41/50
# 4826/4826 [==============================] - 3s 552us/step - loss: 0.8122 - precision: 0.8247 - recall: 0.7503 - accuracy: 0.2694
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,precision,recall,accuracy
# Epoch 42/50
# 4826/4826 [==============================] - 3s 541us/step - loss: 0.8972 - precision: 0.8102 - recall: 0.7478 - accuracy: 0.2586
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,precision,recall,accuracy
# Epoch 43/50
# 4826/4826 [==============================] - 3s 519us/step - loss: 0.8043 - precision: 0.8387 - recall: 0.7756 - accuracy: 0.2547
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,precision,recall,accuracy
# Epoch 44/50
# 4826/4826 [==============================] - 3s 555us/step - loss: 0.7006 - precision: 0.8535 - recall: 0.7955 - accuracy: 0.2527
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,precision,recall,accuracy
# Epoch 45/50
# 4826/4826 [==============================] - 3s 576us/step - loss: 0.7257 - precision: 0.8427 - recall: 0.7830 - accuracy: 0.2450
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,precision,recall,accuracy
# Epoch 46/50
# 4826/4826 [==============================] - 3s 559us/step - loss: 0.7556 - precision: 0.8391 - recall: 0.7758 - accuracy: 0.2371
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,precision,recall,accuracy
# Epoch 47/50
# 4826/4826 [==============================] - 3s 543us/step - loss: 0.7637 - precision: 0.8418 - recall: 0.7857 - accuracy: 0.2405
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,precision,recall,accuracy
# Epoch 48/50
# 4826/4826 [==============================] - 3s 526us/step - loss: 0.7520 - precision: 0.8407 - recall: 0.7849 - accuracy: 0.2293
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,precision,recall,accuracy
# Epoch 49/50
# 4826/4826 [==============================] - 3s 539us/step - loss: 0.7097 - precision: 0.8535 - recall: 0.7987 - accuracy: 0.2316
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,precision,recall,accuracy
# Epoch 50/50
# 4826/4826 [==============================] - 3s 527us/step - loss: 0.8167 - precision: 0.8272 - recall: 0.7690 - accuracy: 0.2367
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,precision,recall,accuracy

# %%
reds = model.evaluate(x = x_test, y = y_test)

F1 = 2 * (preds[1] * preds[2]) / (preds[1] + preds[2])
print('Precision', preds[1])
print('Recall}', preds[2])
print('F1',F1)
# Out:
# 189/189 [==============================] - 0s 451us/step - loss: 0.3002 - precision: 0.9872 - recall: 0.9042 - accuracy: 0.3248
# Precision 0.9871516227722168
# Recall} 0.9041935801506042
# F1 0.9438532517136823

# %%
pd.DataFrame(history.history).plot(figsize = (8, 5))
plt.grid(True)
plt.gca().set_ylim(0, 2)
plt.show()
